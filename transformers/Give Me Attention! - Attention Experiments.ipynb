# %% [markdown]
# # Give me Attention!
#
# Contributor: michaelmenzel@google.com
#
# Various experiments which explore attention mechanisms and their influence on prediction accuracy and complexity.

# %%
import matplotlib.pyplot as plt

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

# %% [markdown]
# ## Attention

# %%
#q = tf.constant([[[1, 1], [1, 1]]], dtype=tf.float32)
q = k = v = tf.constant([
                         [[0.5, 0.2, 0.1], 
                          [0.3, 0.6, 0.5],
                          [0.4, 0.7, 0.3]]
                         ], dtype=tf.float32)
mask = tf.cast(tf.constant([[-100, -100, -100], 
                    [-100, 1, 1],
                    [-100, 1, 1]]), tf.float32)
[q, k, v]
# Out:
# [<tf.Tensor: shape=(1, 3, 3), dtype=float32, numpy=
#  array([[[0.5, 0.2, 0.1],
#          [0.3, 0.6, 0.5],
#          [0.4, 0.7, 0.3]]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 3, 3), dtype=float32, numpy=
#  array([[[0.5, 0.2, 0.1],
#          [0.3, 0.6, 0.5],
#          [0.4, 0.7, 0.3]]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 3, 3), dtype=float32, numpy=
#  array([[[0.5, 0.2, 0.1],
#          [0.3, 0.6, 0.5],
#          [0.4, 0.7, 0.3]]], dtype=float32)>]

# %%
mask
# Out:
# <tf.Tensor: shape=(3, 3), dtype=float32, numpy=
# array([[-100., -100., -100.],
#        [-100.,    1.,    1.],
#        [-100.,    1.,    1.]], dtype=float32)>

# %% [markdown]
# ### Scaled Dot Product Attention

# %%
tf.linalg.matmul(q, k, transpose_b=True)
# Out:
# <tf.Tensor: shape=(1, 3, 3), dtype=float32, numpy=
# array([[[0.29999998, 0.32000002, 0.37      ],
#         [0.32000002, 0.70000005, 0.69000006],
#         [0.37      , 0.69000006, 0.74      ]]], dtype=float32)>

# %%
tf.linalg.matmul(q, k, transpose_b=True) / tf.math.sqrt(tf.cast(tf.size(k), tf.float32))
# Out:
# <tf.Tensor: shape=(1, 3, 3), dtype=float32, numpy=
# array([[[0.09999999, 0.10666668, 0.12333333],
#         [0.10666668, 0.23333335, 0.23000002],
#         [0.12333333, 0.23000002, 0.24666667]]], dtype=float32)>

# %%
tf.linalg.matmul((tf.linalg.matmul(q, k, transpose_b=True) / tf.math.sqrt(tf.cast(tf.size(k), tf.float32))), mask, transpose_b=True)
# Out:
# <tf.Tensor: shape=(1, 3, 3), dtype=float32, numpy=
# array([[[-33.       ,  -9.7699995,  -9.7699995],
#         [-57.000008 , -10.203335 , -10.203335 ],
#         [-60.000004 , -11.8566675, -11.8566675]]], dtype=float32)>

# %%
tf.nn.softmax(tf.linalg.matmul((tf.linalg.matmul(q, k, transpose_b=True) / tf.math.sqrt(tf.cast(tf.size(k), tf.float32))), mask, transpose_b=True))
# Out:
# <tf.Tensor: shape=(1, 3, 3), dtype=float32, numpy=
# array([[[4.0767060e-11, 5.0000000e-01, 5.0000000e-01],
#         [2.3737404e-21, 5.0000000e-01, 5.0000000e-01],
#         [6.1742510e-22, 5.0000000e-01, 5.0000000e-01]]], dtype=float32)>

# %%
def scaled_dot_product_attention(q, k, v):
  d_k = tf.cast(tf.size(k), tf.float32)
  return tf.linalg.matmul(tf.nn.softmax(tf.linalg.matmul(q, k, transpose_b=True) / tf.math.sqrt(d_k)), v)

# %%
scaled_dot_product_attention(q, k, v)
# Out:
# <tf.Tensor: shape=(1, 3, 3), dtype=float32, numpy=
# array([[[0.        , 0.43333334, 0.26666668],
#         [0.        , 0.46052033, 0.28401512],
#         [0.        , 0.46014136, 0.28300965]]], dtype=float32)>

# %%
test_images = [tf.random.uniform((3, 3)) for i in range(10)]

fig, axs = plt.subplots(nrows=2, ncols=len(test_images), figsize=(20, 5),
                        subplot_kw={'xticks': [], 'yticks': []})
for i in range(len(axs[0,:])):
  axs[0,i].imshow(test_images[i], cmap='inferno')
  axs[1,i].imshow(scaled_dot_product_attention(test_images[i], test_images[i], test_images[i]), cmap='inferno')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Multi-Head Attention

# %%
def multi_head_attention(q, k, v, d_model):
  qw = tf.keras.layers.Dense(d_model, use_bias=False)(q)
  kw = tf.keras.layers.Dense(d_model, use_bias=False)(k)
  vw = tf.keras.layers.Dense(d_model, use_bias=False)(v)
  return tf.keras.layers.Dense(d_model, use_bias=False)(scaled_dot_product_attention(qw, kw, vw))

# %%
multi_head_attention(q, k, v, 2)
# Out:
# <tf.Tensor: shape=(1, 2, 2), dtype=float32, numpy=
# array([[[-0.00208041,  0.20830968],
#         [-0.01465899,  0.1277632 ]]], dtype=float32)>

# %% [markdown]
# ### MNIST Attention

# %%
mnist_train, mnist_test = tfds.load("mnist", split=["train", "test"], as_supervised=True)

mnist_train = mnist_train.map(lambda x, y: (tf.squeeze(x/255, axis=-1), y))
mnist_train_batched = mnist_train.batch(128).prefetch(tf.data.AUTOTUNE)
mnist_test = mnist_test.map(lambda x, y: (tf.squeeze(x/255, axis=-1), y))
mnist_test_batched = mnist_test.batch(128).prefetch(tf.data.AUTOTUNE)

mnist_train_batched
# Out:
# Downloading and preparing dataset mnist/3.0.1 (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to /root/tensorflow_datasets/mnist/3.0.1...
# WARNING:absl:Dataset mnist is hosted on GCS. It will automatically be downloaded to your
# local data directory. If you'd instead prefer to read directly from our public
# GCS bucket (recommended if you're running on GCP), you can instead pass
# `try_gcs=True` to `tfds.load` or set `data_dir=gs://tfds-data/datasets`.
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# #### What does scaled dot product attention look like on MNIST?

# %%
fig, axs = plt.subplots(nrows=2, ncols=10, figsize=(20, 5),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, sample in enumerate(mnist_test.take(10)):
  axs[0,i].imshow(sample[0], cmap='inferno')
  axs[1,i].imshow(scaled_dot_product_attention(sample[0], sample[0], sample[0]), cmap='inferno')

fig.show()

# %%
num_heads = 3
d_model = 28*num_heads

def build_model(with_mha=True, trainable_mlp=False):
  input = tf.keras.Input(shape=(28,28))

  if with_mha:
    mha = multi_head_attention(input, input, input, d_model)
    output_mha = tf.split(mha, num_heads, axis=-1, name='mha')
    flatten = tf.keras.layers.Flatten()(mha)
  else:
    output_mha = tf.ones_like(input, name='mha')
    flatten = tf.keras.layers.Flatten()(input)

  if trainable_mlp:
    output = tf.keras.layers.Dense(10, activation='softmax', name='class_one_hot')(flatten)
  else:
    output = tf.keras.layers.Dense(10, activation='softmax', name='class_one_hot', trainable=False, use_bias=False, kernel_initializer=tf.keras.initializers.Ones())(flatten)

  model = tf.keras.Model(inputs=input, outputs={'class_one_hot': output, 'mha': output_mha})
  model.summary()
  return model

def plot_test_sample(model, with_mha=True):
  mha_dims = num_heads if with_mha else 1
  fig, axs = plt.subplots(nrows=1+mha_dims, ncols=10, figsize=(20, 5),
                        subplot_kw={'xticks': [], 'yticks': []})

  for i, sample in enumerate(mnist_test.batch(1).take(10)):
    axs[0,i].imshow(sample[0][0], cmap='inferno')
    predicted = model(sample[0])
    if with_mha:
      for j in range(num_heads):
        axs[1+j,i].imshow(predicted['mha'][j][0], cmap='inferno')
    else:
      axs[1,i].imshow(predicted['mha'][0], vmin=0, vmax=1, cmap='inferno')
    print(f'actual: {sample[1][0]}, predicted: {tf.argmax(predicted["class_one_hot"][0])}')

def run_experiment(with_mha=True, trainable_mlp=False, epochs=10):
  model = build_model(with_mha, trainable_mlp)
  mha_metrics = [None for i in range(num_heads)] if with_mha else None
  model.compile(optimizer='adam', 
                loss={'class_one_hot': tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 'mha':  lambda x,y: 0}, 
                metrics={'class_one_hot': tf.keras.metrics.SparseCategoricalAccuracy(), 'mha': mha_metrics})
  model.fit(mnist_train_batched, validation_data=mnist_test_batched, epochs=epochs)
  return model

# %% [markdown]
# #### Does multi-head attention learn?

# %%
mha_only_model = run_experiment(epochs=3)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28)]     0           []
#
#  dense_5 (Dense)                (None, 28, 84)       2352        ['input_1[0][0]']
#
#  tf.compat.v1.size (TFOpLambda)  ()                  0           ['dense_5[0][0]']
#
#  dense_4 (Dense)                (None, 28, 84)       2352        ['input_1[0][0]']
#
#  tf.cast (TFOpLambda)           ()                   0           ['tf.compat.v1.size[0][0]']
#
#  tf.linalg.matmul (TFOpLambda)  (None, 28, 28)       0           ['dense_4[0][0]',
#                                                                   'dense_5[0][0]']
#
#  tf.math.sqrt (TFOpLambda)      ()                   0           ['tf.cast[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 28, 28)       0           ['tf.linalg.matmul[0][0]',
#                                                                   'tf.math.sqrt[0][0]']
#
#  tf.nn.softmax (TFOpLambda)     (None, 28, 28)       0           ['tf.math.truediv[0][0]']
#
#  dense_6 (Dense)                (None, 28, 84)       2352        ['input_1[0][0]']
#
#  tf.linalg.matmul_1 (TFOpLambda  (None, 28, 84)      0           ['tf.nn.softmax[0][0]',
#  )                                                                'dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 28, 84)       7056        ['tf.linalg.matmul_1[0][0]']
#
#  flatten (Flatten)              (None, 2352)         0           ['dense_7[0][0]']
#
#  class_one_hot (Dense)          (None, 10)           23520       ['flatten[0][0]']
#
#  tf.split (TFOpLambda)          [(None, 28, 28),     0           ['dense_7[0][0]']
#                                  (None, 28, 28),
#                                  (None, 28, 28)]
#
# ==================================================================================================
# Total params: 37,632
# Trainable params: 14,112
# Non-trainable params: 23,520
# __________________________________________________________________________________________________
# Epoch 1/3
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 469/469 [==============================] - 9s 16ms/step - loss: 2.3026 - class_one_hot_loss: 2.3026 - tf.split_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.0987 - val_loss: 2.3026 - val_class_one_hot_loss: 2.3026 - val_tf.split_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.0980
# Epoch 2/3
# 469/469 [==============================] - 4s 7ms/step - loss: 2.3026 - class_one_hot_loss: 2.3026 - tf.split_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.0987 - val_loss: 2.3026 - val_class_one_hot_loss: 2.3026 - val_tf.split_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.0980
# Epoch 3/3
# 469/469 [==============================] - 3s 7ms/step - loss: 2.3026 - class_one_hot_loss: 2.3026 - tf.split_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.0987 - val_loss: 2.3026 - val_class_one_hot_loss: 2.3026 - val_tf.split_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.0980

# %%
plot_test_sample(mha_only_model)
# Out:
# actual: 2, predicted: 0
# actual: 0, predicted: 0
# actual: 4, predicted: 0
# actual: 8, predicted: 0
# actual: 7, predicted: 0
# actual: 6, predicted: 0
# actual: 0, predicted: 0
# actual: 6, predicted: 0
# actual: 3, predicted: 0
# actual: 1, predicted: 0

# %% [markdown]
# #### Does multi-head attention help to learn?

# %% [markdown]
# We get a baseline with a single-layer MLP:

# %%
mlp_model = run_experiment(with_mha=False, trainable_mlp=True, epochs=20)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 28, 28)]     0           []
#
#  flatten_1 (Flatten)            (None, 784)          0           ['input_2[0][0]']
#
#  class_one_hot (Dense)          (None, 10)           7850        ['flatten_1[0][0]']
#
#  tf.ones_like (TFOpLambda)      (None, 28, 28)       0           ['input_2[0][0]']
#
# ==================================================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 469/469 [==============================] - 3s 7ms/step - loss: 0.6857 - class_one_hot_loss: 0.6857 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8263 - val_loss: 0.3872 - val_class_one_hot_loss: 0.3872 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.8993
# Epoch 2/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3649 - class_one_hot_loss: 0.3649 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9003 - val_loss: 0.3215 - val_class_one_hot_loss: 0.3215 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9117
# Epoch 3/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3212 - class_one_hot_loss: 0.3212 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9110 - val_loss: 0.2981 - val_class_one_hot_loss: 0.2981 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9177
# Epoch 4/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3009 - class_one_hot_loss: 0.3009 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9159 - val_loss: 0.2863 - val_class_one_hot_loss: 0.2863 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9214
# Epoch 5/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2887 - class_one_hot_loss: 0.2887 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9192 - val_loss: 0.2793 - val_class_one_hot_loss: 0.2793 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9228
# Epoch 6/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2805 - class_one_hot_loss: 0.2805 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9216 - val_loss: 0.2748 - val_class_one_hot_loss: 0.2748 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9244
# Epoch 7/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2744 - class_one_hot_loss: 0.2744 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9232 - val_loss: 0.2717 - val_class_one_hot_loss: 0.2717 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9253
# Epoch 8/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2697 - class_one_hot_loss: 0.2697 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9245 - val_loss: 0.2695 - val_class_one_hot_loss: 0.2695 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9254
# Epoch 9/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2659 - class_one_hot_loss: 0.2659 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9255 - val_loss: 0.2679 - val_class_one_hot_loss: 0.2679 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9260
# Epoch 10/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2628 - class_one_hot_loss: 0.2628 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9264 - val_loss: 0.2667 - val_class_one_hot_loss: 0.2667 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9262
# Epoch 11/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2601 - class_one_hot_loss: 0.2601 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9274 - val_loss: 0.2657 - val_class_one_hot_loss: 0.2657 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9267
# Epoch 12/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2578 - class_one_hot_loss: 0.2578 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9281 - val_loss: 0.2651 - val_class_one_hot_loss: 0.2651 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9272
# Epoch 13/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2558 - class_one_hot_loss: 0.2558 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9288 - val_loss: 0.2645 - val_class_one_hot_loss: 0.2645 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9278
# Epoch 14/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2540 - class_one_hot_loss: 0.2540 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9294 - val_loss: 0.2641 - val_class_one_hot_loss: 0.2641 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9275
# Epoch 15/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2524 - class_one_hot_loss: 0.2524 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9298 - val_loss: 0.2639 - val_class_one_hot_loss: 0.2639 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9275
# Epoch 16/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2510 - class_one_hot_loss: 0.2510 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9305 - val_loss: 0.2637 - val_class_one_hot_loss: 0.2637 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9275
# Epoch 17/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2496 - class_one_hot_loss: 0.2496 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9308 - val_loss: 0.2635 - val_class_one_hot_loss: 0.2635 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9273
# Epoch 18/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2484 - class_one_hot_loss: 0.2484 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9312 - val_loss: 0.2635 - val_class_one_hot_loss: 0.2635 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9280
# Epoch 19/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2473 - class_one_hot_loss: 0.2473 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9316 - val_loss: 0.2634 - val_class_one_hot_loss: 0.2634 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9277
# Epoch 20/20
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2463 - class_one_hot_loss: 0.2463 - tf.ones_like_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9319 - val_loss: 0.2635 - val_class_one_hot_loss: 0.2635 - val_tf.ones_like_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9276

# %%
plot_test_sample(mlp_model, with_mha=False)
# Out:
# actual: 2, predicted: 2
# actual: 0, predicted: 0
# actual: 4, predicted: 4
# actual: 8, predicted: 8
# actual: 7, predicted: 7
# actual: 6, predicted: 6
# actual: 0, predicted: 0
# actual: 6, predicted: 6
# actual: 3, predicted: 3
# actual: 1, predicted: 1

# %% [markdown]
# #### How does multi-head attention improve learning?

# %%
mha_model = run_experiment(with_mha=True, trainable_mlp=True, epochs=30)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 28, 28)]     0           []
#
#  dense_9 (Dense)                (None, 28, 84)       2352        ['input_3[0][0]']
#
#  tf.compat.v1.size_1 (TFOpLambd  ()                  0           ['dense_9[0][0]']
#  a)
#
#  dense_8 (Dense)                (None, 28, 84)       2352        ['input_3[0][0]']
#
#  tf.cast_1 (TFOpLambda)         ()                   0           ['tf.compat.v1.size_1[0][0]']
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 28, 28)      0           ['dense_8[0][0]',
#  )                                                                'dense_9[0][0]']
#
#  tf.math.sqrt_1 (TFOpLambda)    ()                   0           ['tf.cast_1[0][0]']
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 28, 28)      0           ['tf.linalg.matmul_2[0][0]',
#                                                                   'tf.math.sqrt_1[0][0]']
#
#  tf.nn.softmax_1 (TFOpLambda)   (None, 28, 28)       0           ['tf.math.truediv_1[0][0]']
#
#  dense_10 (Dense)               (None, 28, 84)       2352        ['input_3[0][0]']
#
#  tf.linalg.matmul_3 (TFOpLambda  (None, 28, 84)      0           ['tf.nn.softmax_1[0][0]',
#  )                                                                'dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 28, 84)       7056        ['tf.linalg.matmul_3[0][0]']
#
#  flatten_2 (Flatten)            (None, 2352)         0           ['dense_11[0][0]']
#
#  class_one_hot (Dense)          (None, 10)           23530       ['flatten_2[0][0]']
#
#  tf.split_1 (TFOpLambda)        [(None, 28, 28),     0           ['dense_11[0][0]']
#                                  (None, 28, 28),
#                                  (None, 28, 28)]
#
# ==================================================================================================
# Total params: 37,642
# Trainable params: 37,642
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 469/469 [==============================] - 5s 9ms/step - loss: 1.5382 - class_one_hot_loss: 1.5382 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.4744 - val_loss: 0.7938 - val_class_one_hot_loss: 0.7938 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.7614
# Epoch 2/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.6662 - class_one_hot_loss: 0.6662 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8049 - val_loss: 0.5692 - val_class_one_hot_loss: 0.5692 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.8281
# Epoch 3/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.5482 - class_one_hot_loss: 0.5482 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8397 - val_loss: 0.5027 - val_class_one_hot_loss: 0.5027 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.8460
# Epoch 4/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4798 - class_one_hot_loss: 0.4798 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8607 - val_loss: 0.4450 - val_class_one_hot_loss: 0.4450 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.8663
# Epoch 5/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4377 - class_one_hot_loss: 0.4377 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8743 - val_loss: 0.4046 - val_class_one_hot_loss: 0.4046 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.8818
# Epoch 6/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4109 - class_one_hot_loss: 0.4109 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8824 - val_loss: 0.3795 - val_class_one_hot_loss: 0.3795 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.8909
# Epoch 7/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3887 - class_one_hot_loss: 0.3887 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8897 - val_loss: 0.3615 - val_class_one_hot_loss: 0.3615 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.8970
# Epoch 8/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3693 - class_one_hot_loss: 0.3693 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8945 - val_loss: 0.3484 - val_class_one_hot_loss: 0.3484 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9009
# Epoch 9/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3534 - class_one_hot_loss: 0.3534 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.8989 - val_loss: 0.3388 - val_class_one_hot_loss: 0.3388 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9005
# Epoch 10/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3410 - class_one_hot_loss: 0.3410 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9026 - val_loss: 0.3320 - val_class_one_hot_loss: 0.3320 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9019
# Epoch 11/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3314 - class_one_hot_loss: 0.3314 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9055 - val_loss: 0.3269 - val_class_one_hot_loss: 0.3269 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9037
# Epoch 12/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3236 - class_one_hot_loss: 0.3236 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9073 - val_loss: 0.3231 - val_class_one_hot_loss: 0.3231 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9061
# Epoch 13/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3171 - class_one_hot_loss: 0.3171 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9090 - val_loss: 0.3202 - val_class_one_hot_loss: 0.3202 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9082
# Epoch 14/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3117 - class_one_hot_loss: 0.3117 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9107 - val_loss: 0.3179 - val_class_one_hot_loss: 0.3179 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9100
# Epoch 15/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3070 - class_one_hot_loss: 0.3070 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9121 - val_loss: 0.3160 - val_class_one_hot_loss: 0.3160 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9106
# Epoch 16/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3029 - class_one_hot_loss: 0.3029 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9133 - val_loss: 0.3142 - val_class_one_hot_loss: 0.3142 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9113
# Epoch 17/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2993 - class_one_hot_loss: 0.2993 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9144 - val_loss: 0.3126 - val_class_one_hot_loss: 0.3126 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9110
# Epoch 18/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2960 - class_one_hot_loss: 0.2960 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9150 - val_loss: 0.3111 - val_class_one_hot_loss: 0.3111 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9111
# Epoch 19/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2931 - class_one_hot_loss: 0.2931 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9158 - val_loss: 0.3096 - val_class_one_hot_loss: 0.3096 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9127
# Epoch 20/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2904 - class_one_hot_loss: 0.2904 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9165 - val_loss: 0.3081 - val_class_one_hot_loss: 0.3081 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9130
# Epoch 21/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2879 - class_one_hot_loss: 0.2879 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9167 - val_loss: 0.3066 - val_class_one_hot_loss: 0.3066 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9136
# Epoch 22/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.2855 - class_one_hot_loss: 0.2855 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9174 - val_loss: 0.3052 - val_class_one_hot_loss: 0.3052 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9139
# Epoch 23/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2833 - class_one_hot_loss: 0.2833 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9184 - val_loss: 0.3039 - val_class_one_hot_loss: 0.3039 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9142
# Epoch 24/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2812 - class_one_hot_loss: 0.2812 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9191 - val_loss: 0.3026 - val_class_one_hot_loss: 0.3026 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9140
# Epoch 25/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2793 - class_one_hot_loss: 0.2793 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9198 - val_loss: 0.3013 - val_class_one_hot_loss: 0.3013 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9141
# Epoch 26/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2774 - class_one_hot_loss: 0.2774 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9204 - val_loss: 0.3001 - val_class_one_hot_loss: 0.3001 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9145
# Epoch 27/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2756 - class_one_hot_loss: 0.2756 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9208 - val_loss: 0.2988 - val_class_one_hot_loss: 0.2988 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9148
# Epoch 28/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2739 - class_one_hot_loss: 0.2739 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9214 - val_loss: 0.2976 - val_class_one_hot_loss: 0.2976 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9154
# Epoch 29/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2723 - class_one_hot_loss: 0.2723 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9220 - val_loss: 0.2964 - val_class_one_hot_loss: 0.2964 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9158
# Epoch 30/30
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2707 - class_one_hot_loss: 0.2707 - tf.split_1_loss: 0.0000e+00 - class_one_hot_sparse_categorical_accuracy: 0.9222 - val_loss: 0.2952 - val_class_one_hot_loss: 0.2952 - val_tf.split_1_loss: 0.0000e+00 - val_class_one_hot_sparse_categorical_accuracy: 0.9158

# %%
plot_test_sample(mha_model)
# Out:
# actual: 2, predicted: 2
# actual: 0, predicted: 0
# actual: 4, predicted: 3
# actual: 8, predicted: 1
# actual: 7, predicted: 7
# actual: 6, predicted: 6
# actual: 0, predicted: 0
# actual: 6, predicted: 8
# actual: 3, predicted: 5
# actual: 1, predicted: 1
